# %%
wordsRDD = sc.textFile("/FileStore/tables/q1.txt")
data = wordsRDD.flatMap(lambda line: line.split(","))
output = data.map(lambda lines: (lines, lines+'es'))
print(output.collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;truss&#39;, &#39;trusses&#39;), (&#39;bus&#39;, &#39;buses&#39;), (&#39;class&#39;, &#39;classes&#39;), (&#39;lunch&#39;, &#39;lunches&#39;), (&#39;tax&#39;, &#39;taxes&#39;), (&#39;arch&#39;, &#39;arches&#39;)]
# </div>
